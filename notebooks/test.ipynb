# %%
from dotenv import load_dotenv
import os

load_dotenv()
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
LEGILO_USERNAME = os.getenv("LEGILO_USERNAME")
LEGILO_PASSWORD = os.getenv("LEGILO_PASSWORD")

# %%
from serka.dao import DAO

dao = DAO(
	neo4j_user=NEO4J_USERNAME,
	neo4j_password=NEO4J_PASSWORD,
	legilo_user=LEGILO_USERNAME,
	legilo_password=LEGILO_PASSWORD,
)

# %%
dao.rag_query("Describe the land cover map")
# Out:
# 2025-06-16 10:16:09,730 - haystack.core.pipeline.pipeline - INFO - Running component embedder
# 2025-06-16 10:16:09,752 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-06-16 10:16:09,754 - haystack.core.pipeline.pipeline - INFO - Running component reader
# ...
